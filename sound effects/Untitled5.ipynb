# %%
with open(r"D:\munka\MTA\response box\sound effects\sync_beep.dec", "r") as f:
    for line_no, line in enumerate(f.readlines()):
        no = int(int(line.strip()) / 64 + 512)
        
        if line_no > 10000:
            no = 512
        print(f"{no}, ", end="")
        if (line_no + 1) % 20 == 0:
            print()
# Out:
# 512, 502, 486, 486, 501, 532, 554, 560, 548, 507, 455, 392, 403, 506, 651, 713, 621, 392, 202, 305,
# 687, 1012, 819, 297, 13, 122, 427, 765, 946, 863, 584, 250, 75, 140, 369, 654, 845, 822, 614, 332,
# 156, 191, 385, 644, 835, 838, 659, 394, 208, 215, 381, 620, 813, 837, 683, 432, 237, 221, 366, 590,
# 783, 827, 696, 460, 259, 223, 349, 559, 753, 814, 704, 483, 278, 225, 334, 530, 722, 799, 715, 512,
# 303, 223, 308, 495, 695, 795, 731, 536, 317, 219, 292, 474, 677, 786, 733, 547, 334, 232, 293, 459,
# 647, 763, 735, 573, 364, 244, 284, 440, 627, 751, 737, 590, 388, 263, 287, 421, 591, 722, 746, 635,
# 436, 279, 267, 385, 567, 723, 761, 654, 456, 291, 267, 376, 553, 710, 758, 666, 478, 308, 267, 361,
# 530, 690, 752, 679, 502, 327, 268, 347, 508, 671, 747, 690, 525, 348, 275, 337, 486, 648, 737, 701,
# 552, 371, 276, 320, 464, 633, 734, 709, 567, 389, 288, 318, 442, 599, 715, 721, 604, 424, 297, 299,
# ...

# %%
print(line_no)
# Out:
# 981
